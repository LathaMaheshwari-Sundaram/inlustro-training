# %%
 import numpy as np
 import pandas as pd
 import seaborn as sns
 import matplotlib.pyplot as plt
 det=pd.read_csv("/content/Salary_Data (1).csv")
 det.isnull().sum()
 det.head(6)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642

# %%
det.tail(4)
# Out:
#     YearsExperience  Salary
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
det
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
det.dtypes
# Out:
# YearsExperience    float64
# Salary               int64
# dtype: object

# %%
det.shape
# Out:
# (30, 2)

# %%
drdet=det[det.duplicated()]
print("new row",drdet.shape)
# Out:
# new row (0, 2)

# %%
det.count()
# Out:
# YearsExperience    30
# Salary             30
# dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.boxplot(data=det[["YearsExperience"]],palette="muted")
plt.title("boxplot for salary vs experience")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(data=det,x="Salary",palette="muted")
plt.title("countplot for salary ")
plt.show()
# Out:
# <ipython-input-11-7c858d0e1cc4>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=det,x="Salary",palette="muted")

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=det,x="Salary",y="YearsExperience",palette="coolwarm")
plt.title("barplot for salary vs experience")
plt.show()
# Out:
# <ipython-input-13-1239df9dbded>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=det,x="Salary",y="YearsExperience",palette="coolwarm")

# %%
plt.figure(figsize=(8,5))
sns.histplot(det["Salary"],bins=30,kde=True,palette="coolwarm")
plt.title("histogram for salary ",fontsize=16)
plt.show()
# Out:
# <ipython-input-14-fb78c021a4c1>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(det["Salary"],bins=30,kde=True,palette="coolwarm")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import train_test_split

x=det["YearsExperience"]
y=det["Salary"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test.values.reshape(-1,1))
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)
print(mse)
print(r2)
# Out:
# 37784662.46621314
# 0.9414466227178214

# %%
plt.scatter(x,y,color="blue")
plt.plot(x_test,y_pred,color="red")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("salary vs experience")
plt.show()
